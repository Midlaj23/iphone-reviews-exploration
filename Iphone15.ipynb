# %%
import pandas as pd

# %%
df = pd.read_json(r"C:\Users\Lenovo\Documents\Web scraping\IMDB\Iphone15.json")
df
# Out:
#                 Buyer_name  Rating  \
# 0         Mousam  Guha Roy       4
# 1          Prithivi Boruah       5
# 2                   Ajin V       5
# 3    Sheetla Prasad Maurya       4
# 4            mohit  yadav        5
# ..                     ...     ...
# 182       Abhishek  Parmar       3
# 183              Aman Rana       5
# 184            Unknown 711       5
# 185               Shinz PK       5
# 186         Anjali  Singh        5
#
#                                                 Review
# 0                                            Very nice
# 1                 Camera Quality Is Improved Loving It
# 2                                 High quality camera😍
# 3    Best mobile phoneCamera quality is very nice B...
# 4                                              Nice ❤️
# ..                                                 ...
# 182  Battery is not good need to charger 3 times a ...
# 183                                     Money worth it
# ...
